# %%
import pandas as pd

# %%
df3=pd.read_csv('datasets/imdb.csv')
df3
# Out:
#       id                                       name   genre  year imdb_rating
# 0      1                                     Avatar  action  2009         7.9
# 1      2                             Jurassic World  action  2015         7.3
# 2      3                               The Avengers  action  2012         8.1
# 3      4                            The Dark Knight  action  2008         9.0
# 4      5  Star Wars: Episode I - The Phantom Menace  action  1999         6.6
# ..   ...                                        ...     ...   ...         ...
# 215  216                                   Hannibal   drama  2001         6.7
# 216  217                        Catch Me If You Can   drama  2002         8.0
# 217  218                                  Big Daddy   drama  1999         6.4
# 218  219                                      Se7en   drama  1995         8.6
# 219  220                                      Seven   drama  1979         6.1
#
# [220 rows x 5 columns]

# %%
df3.head(10)
# Out:
#    id                                       name   genre  year imdb_rating
# 0   1                                     Avatar  action  2009         7.9
# 1   2                             Jurassic World  action  2015         7.3
# 2   3                               The Avengers  action  2012         8.1
# 3   4                            The Dark Knight  action  2008         9.0
# 4   5  Star Wars: Episode I - The Phantom Menace  action  1999         6.6
# 5   6                                  Star Wars  action  1977         8.7
# 6   7                    Avengers: Age of Ultron  action  2015         7.9
# 7   8                      The Dark Knight Rises  action  2012         8.5
# 8   9  Pirates of the Caribbean: Dead Mans Chest  action  2006         7.3
# 9  10                                 Iron Man 3  action  2013         7.3

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           220 non-null    int64
#  1   name         220 non-null    object
#  2   genre        220 non-null    object
#  3   year         220 non-null    int64
#  4   imdb_rating  220 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 6.1+ KB

# %%
year = df3['year']

# %%
year2 = df3.year
year2
# Out:
# 0      2009
# 1      2015
# 2      2012
# 3      2008
# 4      1999
#        ...
# 215    2001
# 216    2002
# 217    1999
# 218    1995
# 219    1979
# Name: year, Length: 220, dtype: int64

# %%
df3.iloc[2]
# Out:
# id                        3
# name           The Avengers
# genre                action
# year                   2012
# imdb_rating             8.1
# Name: 2, dtype: object

# %%
type(df3.iloc[2])
# Out:
# pandas.core.series.Series

# %%
clinica_del_este = pd.Series([100, 51, 81, 88, 51, 112])
clinica_del_este
# Out:
# 0    100
# 1     51
# 2     81
# 3     88
# 4     51
# 5    112
# dtype: int64

# %%
type(clinica_del_este)
# Out:
# pandas.core.series.Series

# %%
new_d = df3[['year', 'genre']]

# %%
new_d
# Out:
#      year   genre
# 0    2009  action
# 1    2015  action
# 2    2012  action
# 3    2008  action
# 4    1999  action
# ..    ...     ...
# 215  2001   drama
# 216  2002   drama
# 217  1999   drama
# 218  1995   drama
# 219  1979   drama
#
# [220 rows x 2 columns]

# %%
type(new_d)
# Out:
# pandas.core.frame.DataFrame

# %%
avengers = df3.iloc[2]
avengers
# Out:
# id                        3
# name           The Avengers
# genre                action
# year                   2012
# imdb_rating             8.1
# Name: 2, dtype: object

# %%
df3.iloc[3:7]
# Out:
#    id                                       name   genre  year imdb_rating
# 3   4                            The Dark Knight  action  2008         9.0
# 4   5  Star Wars: Episode I - The Phantom Menace  action  1999         6.6
# 5   6                                  Star Wars  action  1977         8.7
# 6   7                    Avengers: Age of Ultron  action  2015         7.9

# %%
df3.iloc[:7]
# Out:
#    id                                       name   genre  year imdb_rating
# 0   1                                     Avatar  action  2009         7.9
# 1   2                             Jurassic World  action  2015         7.3
# 2   3                               The Avengers  action  2012         8.1
# 3   4                            The Dark Knight  action  2008         9.0
# 4   5  Star Wars: Episode I - The Phantom Menace  action  1999         6.6
# 5   6                                  Star Wars  action  1977         8.7
# 6   7                    Avengers: Age of Ultron  action  2015         7.9

# %%
df3.iloc[:21:3]
# Out:
#     id                                          name   genre  year imdb_rating
# 0    1                                        Avatar  action  2009         7.9
# 3    4                               The Dark Knight  action  2008         9.0
# 6    7                       Avengers: Age of Ultron  action  2015         7.9
# 9   10                                    Iron Man 3  action  2013         7.3
# 12  13  Star Wars: Episode III - Revenge of the Sith  action  2005         7.7
# 15  16                               American Sniper  action  2014         7.4
# 18  19                       Guardians of the Galaxy  action  2014         8.1

# %%
df3[df3.genre == 'horror']
# Out:
#       id                                               name   genre  year  \
# 97    98                                        World War Z  horror  2013
# 98    99                                  What Lies Beneath  horror  2000
# 99   100                                           Gremlins  horror  1984
# 100  101                            The Blair Witch Project  horror  1999
# 101  102                                      The Conjuring  horror  2013
# 102  103                                           The Ring  horror  2002
# 103  104                                         The Grudge  horror  2004
# 104  105                                Paranormal Activity  horror  2007
# 105  106  Interview with the Vampire: The Vampire Chroni...  horror  1994
# 106  107                              Paranormal Activity 3  horror  2011
# 107  108                                             Scream  horror  1996
# 108  109                                             Jaws 2  horror  1978
# ...

# %%
df3[df3.year > 2013]
# Out:
#       id                                 name    genre  year imdb_rating
# 1      2                       Jurassic World   action  2015         7.3
# 6      7              Avengers: Age of Ultron   action  2015         7.9
# 15    16                      American Sniper   action  2014         7.4
# 16    17                        Furious Seven   action  2015         7.4
# 18    19              Guardians of the Galaxy   action  2014         8.1
# 35    36  Captain America: The Winter Soldier   action  2014         7.8
# 36    37                       The Lego Movie   action  2014         7.8
# 40    41      Transformers: Age of Extinction   action  2014         5.8
# 42    43                           Maleficent   action  2014         7.0
# 47    48           X-Men: Days of Future Past   action  2014         8.1
# 55    56                           Inside Out   comedy  2015         8.6
# 57    58                              Minions   comedy  2015         6.7
# ...

# %%
df3[(df3.year > 2013) & (df3.genre == 'drama')]
# Out:
#       id                            name  genre  year imdb_rating
# 199  200  Dawn of the Planet of the Apes  drama  2014         7.7
# 200  201                    Interstellar  drama  2014         8.7
# 213  214                       Gone Girl  drama  2014         8.2

# %%
df3[(df3.imdb_rating > 7.7)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-7bfda7063111> in <module>
# ----> 1 df3[(df3.imdb_rating > 7.7)]
#
# c:\users\natik\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# c:\users\natik\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ...

# %%
df3[df3.name.isin(['American Sniper', "Jurassic World"])].reset_index()
# Out:
#    index  id             name   genre  year imdb_rating
# 0      1   2   Jurassic World  action  2015         7.3
# 1     15  16  American Sniper  action  2014         7.4

# %%
df3.name.isin(['American Sniper', "Jurassic World"])
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 215    False
# 216    False
# 217    False
# 218    False
# 219    False
# Name: name, Length: 220, dtype: bool
