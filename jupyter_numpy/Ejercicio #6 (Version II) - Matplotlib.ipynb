# %% [markdown]
# # Ejercicio #6 - Matplotlib

# %% [markdown]
# ## Parte 1
#
# Continuamos con el proyecto de la cafeteria Matplotslip.
#
# 1- MatplotSip lleva un registro de cuántas personas pagan con tarjeta de crédito, dinero en efectivo, Apple pay u otros métodos. Esto se le da en las listas `payment_method_names` y de `payment_method_freqs`.
#
# Mostrar la lista de `payment_method_freqs` en forma de gráfico circular.
#
# 2- Ahora, ajuste los ejes para que sean iguales.
#
# 3- Añada una leyenda al gráfico que hizo en el ejercicio anterior pasando una lista de etiquetas a `plt.legend`. Para las etiquetas, utilice la lista `payment_method_names`.
#
# 4- Agregue un porcentaje a cada rebanada usando el parámetro `autopct` de Matplotlib. Vaya con un punto decimal de precisión.

# %%
from matplotlib import pyplot as plt

payment_method_names = ["Card Swipe", "Cash", "Apple Pay", "Other"]
payment_method_freqs = [270, 77, 32, 11]

## Realice su grafico aqui

# %%
plt.pie(payment_method_freqs, colors=["yellow", "blue", "red", "green"], labels=payment_method_names)
plt.axis('equal')
plt.legend(payment_method_names)
plt.show()

# %% [markdown]
# ## Parte 2
#
# Imaginemos que estás trabajando como profesor de matemáticas en una escuela secundaria. Quieres mostrar métricas importantes sobre tu clase actual y las que has enseñado en años anteriores, con el fin de entender patrones y tendencias que pueden no ser visibles con sólo ver los números en una hoja de cálculo.
#
# En este proyecto, examinarás algunos gráficos que hemos creado, y luego los recrearás usando Matplotlib. Esto le dará la oportunidad de practicar con los tipos de graficos y propiedades que exploramos.
#
# ## Grafico de Barras de Errores
#
# Primero, vamos a ver este gráfico:
#
# ![Screen%20Shot%202019-11-08%20at%208.50.07%20AM.png](attachment:Screen%20Shot%202019-11-08%20at%208.50.07%20AM.png)
#
# Los datos que necesitará para recrear este gráfico están en las listas `past_years_averages`, `years`, y `error`.
#
# Tenemos entonces los siguientes datos iniciales
#
# ```
# from matplotlib import pyplot as plt
#
# past_years_averages = [82, 84, 83, 86, 74, 84, 90]
# years = [2000, 2001, 2002, 2003, 2004, 2005, 2006]
# error = [1.5, 2.1, 1.2, 3.2, 2.3, 1.7, 2.4]
# ```
#
# 1- Cree una figura con ancho de 10 y alto de 8
#
# 2- Graficque barras azules que tiene los altos listados en `past_years_averages`
#
# 3- Añada una barra de error con un tamaño de `cap` de 5 y anchoes correspondientes a las lista `error`
#
# 4- Configure los `axis` para que vayan de `-0.5` a `6.5` en el eje-x y de `70` a `95` en el eje-y
#
# 5- Cree un objeto `ax` usando `plt.subplot()`. use `ax` para configurar el eje-x para que sea `range(len(years))` y los labels del eje-x para que sea la lista `years`
#
# 6- Añada el titulo `Final Exam Averages`, el label del eje-x para que sea `"Year"` y el label del eje-y para que sea `"Test average"`
#
# 7- Guarde el grafico en unarchivo llamado `my_bar_chart.png`

# %%
past_years_averages = [82, 84, 83, 86, 74, 84, 90]
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006]
error = [1.5, 2.1, 1.2, 3.2, 2.3, 1.7, 2.4]
x_values = range(len(past_years_averages))
y_err = [0.6, 0.9, 0.4, 0, 0.9, 0, 0]

# haga la grafica aqui
plt.figure(figsize=(10,8))
ax = plt.subplot()
plt.axis([-0.5, 6.5, 70, 95])
ax.set_xticks(x_values)
ax.set_xticklabels(years)
plt.bar(x_values, past_years_averages, yerr=y_err, capsize=5)
plt.title("Final Exam Averages")
plt.xlabel("Year")
plt.ylabel("Test average")
plt.show()
plt.savefig("final-exam-averages")

# %% [markdown]
# ## Barras Lado a Lado
#
# Ahora, vamos a ver el siguiente gráfico.
#
# ![Screen%20Shot%202019-11-08%20at%208.53.41%20AM.png](attachment:Screen%20Shot%202019-11-08%20at%208.53.41%20AM.png)
#
# Esto muestra las diferencias en los resultados promedio de las pruebas entre los estudiantes que fueron a dos escuelas secundarias diferentes antes de matricularse en su escuela secundaria.
#
# Los datos que necesitará para recrear esta tabla están en las listas `middle_school_a`, `middle_school_b`, y `unit_topics`. Asi mismo hicimos un metodo llamada `create_x` que hace las listas `school_a_x` y `school_b_x` que determinaran donde poner las barras para cada escuela en el eje `x`
#
#
# 1. Crea una figura de ancho `10` y alto `8`.
#
#
# 2. Crear un conjunto de ejes `y` guardarlos en un `ax`.
#
#
# 3. Trace un conjunto de barras que representen la `middle_school_a` y un conjunto que represente `middle_school_b` una al lado de la otra en la misma gráfica.
#
#
# 4. Crear una nueva lista de valores `x` llamada `middle_x`, que son los valores en el centro de `school_a_x` y `school_b_x`. Aquí es donde colocaremos los x-ticks. Mira el gráfico anterior para ver la ubicación.
#
#
# 5. Establecer los x-ticks como la lista `middle_x`.
#
#
# 6. Configure las etiquetas x-tick para que sean la lista `unit_topics`.
#
#
# 7. Cree una leyenda, como se muestra en el gráfico final, que identifique el primer conjunto de barras `Middle School A` y el segundo conjunto de barras `Middle School B`.
#
#
# 8. Cree un título ("`Test Averages on Different Units`"), una etiqueta del eje `x` ("`Unit`") y una etiqueta del eje `y` ("`Test Average`").
#
#
# 9. Guarde su figura en un archivo llamado `my_side_by_side.png`.

# %%
unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
middle_school_a = [80, 85, 84, 83, 86]
middle_school_b = [73, 78, 77, 82, 86]

def create_x(t, w, n, d):
    return [t*x + w*n for x in range(d)]
school_a_x = create_x(2, 0.8, 1, 5)
school_b_x = create_x(2, 0.8, 2, 5)


# haga la grafica aqui

# %% [markdown]
# ## Barras apiladas (stacked)
#
# Ahora, vamos a ver el gráfico siguiente. Esta gráfica muestra el desglose de los estudiantes que obtuvieron As, Bs, Cs, Ds y Fs en cada unidad.
#
# ![Screen%20Shot%202019-11-08%20at%209.14.38%20AM.png](attachment:Screen%20Shot%202019-11-08%20at%209.14.38%20AM.png)
#
# Los datos que necesitará para recrear este gráfico están en las listas `As`, `Bs`, `Cs`, `Ds`, `Fs`, y `unit_topics`.
#
# 1. Las barras `Bs` irán encima de las barras `As`, pero ¿a qué altura empezarán las barras `Cs`, `Ds` y `Fs`?
# La parte inferior de las barras que representan las `Cs` estará a la altura del `As` más el `Bs`. Podemos hacer esto en NumPy con la función `p.add`. `c_bottom`, la altura inicial de las `Cs`, será:
#
# `c_bottom = np.add(As, Bs)`
#
# Debajo de la definición de `c_bottom`, defina `d_bottom`(donde terminan las `Cs`), y `f_bottom`(donde terminan las `Ds`).
#
#
# 2. Crea una figura de ancho `10` y alto `8`.
#
#
# 3. Trace las `As`, `Bs`, `Cs`, `Ds`, `Fs`. Déle a cada uno la lista apropiada que los apilará uno encima del otro.
#
#
# 4. Crear un conjunto de ejes guardarlos en `ax`.
#
#
# 5. Configure los x-ticks para que sean de rango `(len(unit_topics))`.
#
#
# 6. Configure las etiquetas x-tick para que sean los `unit_topics`.
#
#
# 7. Dale al gráfico el título que ves en el gráfico final, y la misma etiqueta del eje `x` y la misma etiqueta del eje `y`.
#
#
# 8. Guarde su figura en un archivo llamado `my_stacked_bar.png`.

# %%
import numpy as np

unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
As = [6, 3, 4, 3, 5]
Bs = [8, 12, 8, 9, 10]
Cs = [13, 12, 15, 13, 14]
Ds = [2, 3, 3, 2, 1]
Fs = [1, 0, 0, 3, 0]

x = range(5)

c_bottom = np.add(As, Bs)

## Inicie el ejercicio aqui

# %% [markdown]
# ## Dos histogramas en un plot
#
# Ahora, vamos a ver el siguiente gráfico. Esto muestra el desglose de las puntuaciones del examen final entre el primer año de enseñanza y el segundo año de enseñanza.
#
# ![Screen%20Shot%202019-11-08%20at%209.27.04%20AM.png](attachment:Screen%20Shot%202019-11-08%20at%209.27.04%20AM.png)
#
# Los datos que necesitará para recrear este gráfico están en las listas `exam_scores1` y `exam_scores2`.
#
# 1. Crea una figura de ancho `10` y alto `8`.
#
#
# 2. Haga un histograma de `exam_scores1`, normalizado, con `12` bins.
#
#
# 3. Haga un histograma de `exam_scores2`, normalizado, con `12` bins.
#
#
# 4. Añadir `histtype = 'step'` a cada llamada `plt.hist`, para hacer más visibles estos histogramas. También podemos hacer las líneas más gruesas ajustando el ancho de línea dentro de las llamadas a `plt.hist`. Fijemos el ancho de línea con `linewidth` en `2` para ambos histogramas.
#
#
# 5. Crear una leyenda que muestre que el primer conjunto de datos es "`1st Yr Teaching`" y el segundo conjunto de datos es "`2nd Yr Teaching`".
#
#
# 6. Añada el título, la etiqueta del eje `x` y la etiqueta del eje `y` que ve en el gráfico final.
#
#
# 7. Guarde su figura en un archivo llamado `my_histogram.png`.

# %%
exam_scores1 = [62.58, 67.63, 81.37, 52.53, 62.98, 72.15, 59.05, 73.85, 97.24, 76.81, 89.34, 74.44, 68.52, 85.13, 90.75, 70.29, 75.62, 85.38, 77.82, 98.31, 79.08, 61.72, 71.33, 80.77, 80.31, 78.16, 61.15, 64.99, 72.67, 78.94]
exam_scores2 = [72.38, 71.28, 79.24, 83.86, 84.42, 79.38, 75.51, 76.63, 81.48,78.81,79.23,74.38,79.27,81.07,75.42,90.35,82.93,86.74,81.33,95.1,86.57,83.66,85.58,81.87,92.14,72.15,91.64,74.21,89.04,76.54,81.9,96.5,80.05,74.77,72.26,73.23,92.6,66.22,70.09,77.2]

## Inicie el ejercicio aqui

# %% [markdown]
# ## Grafico circular etiquetado
#
# Ahora, vamos a ver el siguiente grafico. Esto muestra lo que los estudiantes piensan que es el tema más difícil que se cubre a lo largo de su curso de matemáticas.
#
# ![Screen%20Shot%202019-11-08%20at%209.35.46%20AM.png](attachment:Screen%20Shot%202019-11-08%20at%209.35.46%20AM.png)
#
# Los datos que necesitará para recrear este gráfico están en las listas `unit_topics` y `num_hardest_reported`.
#
# 1. Crea una figura de ancho `10` y alto `8`.
#
#
# 2. Trazar la lista `num_hardest_reported` como un gráfico circular.
#
#
# 3. Poner los axes que sean `'equal'`.
#
#
# 4. Etiquetar las rebanadas con la lista `unit_topics` y poner una etiqueta de porcentaje en cada rebanada, redondeada al `int` más cercano.
#
#
# 5. Añada el título "`Hardest Topics`".
#
#
# 6. Guarde su figura en un archivo llamado `my_pie_chart.png`.

# %%
unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
num_hardest_reported = [1, 3, 10, 15, 1]

## Inicie el ejercicio aqui

# %% [markdown]
# ## Línea con error sombreado
#
# Ahora, vamos a ver el siguiente gráfico. Esto muestra la relación entre el tiempo que los estudiantes dicen haber estudiado y los puntajes que recibieron en sus exámenes finales.
#
# ![Screen%20Shot%202019-11-08%20at%209.42.47%20AM.png](attachment:Screen%20Shot%202019-11-08%20at%209.42.47%20AM.png)
#
# Los datos que necesitará para recrear este gráfico están en las listas `hours_reported` y `exam_scores`.
#
# 1. Crea una figura de ancho `10` y alto `8`.
#
#
# 2. Trace las puntuaciones del examen en el eje `x` y las horas reportadas en el eje `y`, con un ancho de línea `linewidth` de 2.
#
#
# 3. Supongamos que el error en el informe de los estudiantes sobre sus horas de estudio es del `20%`. Cree una lista `hours_lower_bound`, que tiene los elementos de `hours_reported` menos 20%, y una lista `hours_upper_bound`, que tiene los elementos de `hours_reported` más 20%. Puede hacer esto con un list comprenhension.
#
#
# 4. Sombree el área entre `hours_lower_bound` y `hours_upper_bound `con un alfa de `0,2`.
#
#
# 5. Dale al argumento el título '`Time spent studying vs final exam scores`', la etiqueta del eje x '`Score`' y la etiqueta del eje y '`Hours studying (self-reported)`)'.
#
#
# 6. Guarde su figura en un archivo llamado `my_line_graph.png``.

# %%
hours_reported =[3, 2.5, 2.75, 2.5, 2.75, 3.0, 3.5, 3.25, 3.25,  3.5, 3.5, 3.75, 3.75,4, 4.0, 3.75,  4.0, 4.25, 4.25, 4.5, 4.5, 5.0, 5.25, 5, 5.25, 5.5, 5.5, 5.75, 5.25, 4.75]
exam_scores = [52.53, 59.05, 61.15, 61.72, 62.58, 62.98, 64.99, 67.63, 68.52, 70.29, 71.33, 72.15, 72.67, 73.85, 74.44, 75.62, 76.81, 77.82, 78.16, 78.94, 79.08, 80.31, 80.77, 81.37, 85.13, 85.38, 89.34, 90.75, 97.24, 98.31]


## Inicie el ejercicio aqui
