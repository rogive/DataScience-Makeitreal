# %% [markdown]
# # Ejercicio #4 - Matplotlib

# %% [markdown]
# En este proyecto, usted actuará como analista de datos para un minorista de venta de limones en línea llamado Sublime Limes. La gente de todo el mundo puede comprar este producto para obtener las limas más frescas y de mejor calidad entregadas a su puerta. Uno de los jefes de producto de Sublime Limes desea conocer mejor a los clientes y sus hábitos de venta. Usando Matplotlib, crearás diferentes gráficos de líneas (o tal vez, gráficos de limones) para comunicar esta información de manera efectiva.

# %% [markdown]
# 1- Hemos proporcionado algunos datos en diferentes listas. Revise estas listas y trate de entender lo que cada uno representa (ver al final del jupyter).

# %% [markdown]
# ### Nota: Cree todos los pasos en una sola celda con el fin de no tener que re-escribir siempre las listas

# %% [markdown]
# ## Comprender los datos y establecer subtramas

# %% [markdown]
# 2- Cree una figura de ancho `12` y alto `8`.

# %% [markdown]
# 3- Vamos a hacer dos gráficos en una sola figura, dispuestos uno al lado del otro. En otras palabras, la figura tendrá una fila y dos columnas, así:
#
# ![Screenshot%20from%202019-11-04%2011-16-44.png](attachment:Screenshot%20from%202019-11-04%2011-16-44.png)
#
# Escriba el comando para crear el subplot izquierdo (la que correspondería a la grafica con una estrella en nuestra figura de ejemplo). Guarde este subplot en una variable llamada `ax1`.

# %% [markdown]
# 4- Escribe el comando para crear el subplot correcto (el que correspondería al grafico con un cuadrado en nuestra figura de ejemplo). Guardar este subplot en una variable llamada `ax2`.

# %% [markdown]
# ## Visitas de la página en el tiempo

# %% [markdown]
# 5- En el subplot de la izquierda, vamos a trazar el total de visitas a la página durante el año pasado como una línea.
#
# Primero, vamos a crear la lista de valores x, que es `range(len(months))`. Guarda esto en una variable llamada `x_values`.
#
# Asegúrate de que esto ocurre después de la línea donde creaste `ax1`, pero antes de la línea donde has creado `ax2`, para que el gráfico vaya en el subplot de la izquierda.

# %% [markdown]
# 6- Grafica el total de visitas a la página contra estos `x_values` como una línea.

# %% [markdown]
# 7- Cree los marcadores cada línea que le ayudarán a mostrar cada mes como un valor distinto.

# %% [markdown]
# 8- Etiquete el eje x y el eje y con títulos descriptivos de lo que miden.

# %% [markdown]
# 9- Configure las marcas del eje x para que sean `x_values`.

# %% [markdown]
# 10- Etiquete los ticks de los labels del eje x para que sean los nombres almacenados en ellas (`months`) en la lista.

# %% [markdown]
# ## Plotear múltiples especies de limones

# %% [markdown]
# 11- En el subplot de la derecha, vamos a trazar tres líneas en el mismo conjunto de ejes. Los valores de x para las tres líneas corresponderán a los meses, así que podemos usar la lista de valores `x_values` que usamos para el último gráfico.
#
# En un gráfico, cree las tres líneas:
# - número de key limes vendidas vs `x_values`
# - número de limas persas vendidas vs `x_values`
# - número de blood limes vendidas vs `x_values`

# %% [markdown]
# 12- Asegúrate de que esto ocurra después de la línea donde creaste `ax2`, para que vaya en el subplot de la derecha.

# %% [markdown]
# 13- Dé a cada línea un color específico de su elección.

# %% [markdown]
# 14- Añada una leyenda para diferenciar las líneas, etiquetando cada especie de lima.

# %% [markdown]
# 15- Configure las marcas del eje x para que sean los `x_values`, y las etiquetas de las marcas para que sean las de la lista `months`.

# %% [markdown]
# ## Etiquetado y guardado

# %% [markdown]
# 16- Añada un título a cada uno de los dos gráficos que ha creado y ajuste los márgenes para que el texto que ha añadido se vea mejor.

# %% [markdown]
# 17- Ahora, guarde su figura como `png` un nombre de archivo descriptivo.

# %% [markdown]
# ## Escriba aqui su codigo completo y paso a paso

# %%
from matplotlib import pyplot as plt

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

visits_per_month = [9695, 7909, 10831, 12942, 12495, 16794, 14161, 12762, 12777, 12439, 10309, 8724]

# numbers of limes of different species sold each month
key_limes_per_month = [92.0, 109.0, 124.0, 70.0, 101.0, 79.0, 106.0, 101.0, 103.0, 90.0, 102.0, 106.0]
persian_limes_per_month = [67.0, 51.0, 57.0, 54.0, 83.0, 90.0, 52.0, 63.0, 51.0, 44.0, 64.0, 78.0]
blood_limes_per_month = [75.0, 75.0, 76.0, 71.0, 74.0, 77.0, 69.0, 80.0, 63.0, 69.0, 73.0, 82.0]
x_values = range(len(months))

# %%
plt.figure(figsize=(12,8))
ax1 = plt.subplot(1, 2, 1)
plt.plot(x_values, visits_per_month, color = 'blue', marker = "o")
plt.xlabel("Meses")
plt.ylabel("Visitas")
plt.title("Visitas en el año")
ax1.set_xticks(x_values)
ax1.set_xticklabels(months)
ax2 = plt.subplot(1, 2, 2)
plt.plot(x_values, key_limes_per_month, color = 'green', marker = "o")
plt.plot(x_values, persian_limes_per_month, color = 'blue', marker = "o")
plt.plot(x_values, blood_limes_per_month, color = 'yellow', marker = "o")
plt.title("Limones en el año")
ax2.axis([0,12,30,125])
ax2.set_xticks(x_values)
ax2.set_xticklabels(months)
plt.legend(["key limes", "limas persas", "blood limes"], loc= 4)
plt.subplots_adjust(wspace=0.6, hspace=0.8)
plt.savefig("limes")
plt.show()
